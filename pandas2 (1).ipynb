# %%
import pandas as pd
dfemp = pd.read_excel("C:\\Users\\joans\\Downloads\\p2emp.xlsx")

# %%
dfemp
# Out:
#     empid         ename  Unnamed: 2      dept             desig        doj  \
# 0     101       Rajaram         NaN     sales   Sales Executive 2019-01-10
# 1     102         Ramya         NaN     sales   Sales Executive 2021-02-15
# 2     103      Gayathri         NaN  accounts           Manager 2023-01-19
# 3     104       Shabeer         NaN  accounts  Junior Executive 2023-02-26
# 4     105  Suresh Kumar         NaN     sales     Sales Manager 2016-04-29
# 5     106       Kesavan         NaN        IT         Developer 2018-06-30
# 6     106       Kesavan         NaN        IT         Developer 2018-06-30
# 7     107        Naveen         NaN        IT           Testing 2015-08-23
# 8     108         Prema         NaN        IT           Testing 2023-12-17
# 9     109       Charles         NaN     sales     Sales Manager 2024-07-16
# 10    110         Ashok         NaN        IT         Developer 2024-03-13
# ...

# %%
dfemp.drop(columns=['Unnamed: 2', 'Unnamed: 9'], inplace=True)

# %%
dfemp
# Out:
#     empid         ename      dept             desig        doj        doc  \
# 0     101       Rajaram     sales   Sales Executive 2019-01-10 2019-07-11
# 1     102         Ramya     sales   Sales Executive 2021-02-15 2021-08-16
# 2     103      Gayathri  accounts           Manager 2023-01-19        NaT
# 3     104       Shabeer  accounts  Junior Executive 2023-02-26        NaT
# 4     105  Suresh Kumar     sales     Sales Manager 2016-04-29 2016-09-30
# 5     106       Kesavan        IT         Developer 2018-06-30 2018-07-01
# 6     106       Kesavan        IT         Developer 2018-06-30 2018-07-01
# 7     107        Naveen        IT           Testing 2015-08-23 2015-11-24
# 8     108         Prema        IT           Testing 2023-12-17        NaT
# 9     109       Charles     sales     Sales Manager 2024-07-16        NaT
# 10    110         Ashok        IT         Developer 2024-03-13        NaT
# 11    111       Nagaraj        IT         Developer        NaT        NaT
# ...

# %%
dfemp.drop(index=11)
# Out:
#     empid         ename      dept             desig        doj        doc  \
# 0     101       Rajaram     sales   Sales Executive 2019-01-10 2019-07-11
# 1     102         Ramya     sales   Sales Executive 2021-02-15 2021-08-16
# 2     103      Gayathri  accounts           Manager 2023-01-19        NaT
# 3     104       Shabeer  accounts  Junior Executive 2023-02-26        NaT
# 4     105  Suresh Kumar     sales     Sales Manager 2016-04-29 2016-09-30
# 5     106       Kesavan        IT         Developer 2018-06-30 2018-07-01
# 6     106       Kesavan        IT         Developer 2018-06-30 2018-07-01
# 7     107        Naveen        IT           Testing 2015-08-23 2015-11-24
# 8     108         Prema        IT           Testing 2023-12-17        NaT
# 9     109       Charles     sales     Sales Manager 2024-07-16        NaT
# 10    110         Ashok        IT         Developer 2024-03-13        NaT
# 12    104       Shabeer  accounts  Junior Executive 2023-02-26        NaT
#
# ...

# %%
dfemp.drop(index=11,inplace=True)

# %%
dfemp.drop_duplicates()
# Out:
#     empid         ename      dept             desig        doj        doc  \
# 0     101       Rajaram     sales   Sales Executive 2019-01-10 2019-07-11
# 1     102         Ramya     sales   Sales Executive 2021-02-15 2021-08-16
# 2     103      Gayathri  accounts           Manager 2023-01-19        NaT
# 3     104       Shabeer  accounts  Junior Executive 2023-02-26        NaT
# 4     105  Suresh Kumar     sales     Sales Manager 2016-04-29 2016-09-30
# 5     106       Kesavan        IT         Developer 2018-06-30 2018-07-01
# 7     107        Naveen        IT           Testing 2015-08-23 2015-11-24
# 8     108         Prema        IT           Testing 2023-12-17        NaT
# 9     109       Charles     sales     Sales Manager 2024-07-16        NaT
# 10    110         Ashok        IT         Developer 2024-03-13        NaT
#
#      salary  bonus   location        mobile gender
# 0   12000.0   0.10    chennai  7.787543e+09      M
# 1   10000.0   0.15    chennai  9.986744e+09      F
# ...

# %%
dfemp.drop_duplicates(inplace=True)

# %%
dfemp.iloc[0,6]=25000

# %%
dfemp.insert(8,column='bonusamt',value=dfemp.salary*dfemp.bonus)

# %%
dfemp
# Out:
#     empid         ename      dept             desig        doj        doc  \
# 0     101       Rajaram     sales   Sales Executive 2019-01-10 2019-07-11
# 1     102         Ramya     sales   Sales Executive 2021-02-15 2021-08-16
# 2     103      Gayathri  accounts           Manager 2023-01-19        NaT
# 3     104       Shabeer  accounts  Junior Executive 2023-02-26        NaT
# 4     105  Suresh Kumar     sales     Sales Manager 2016-04-29 2016-09-30
# 5     106       Kesavan        IT         Developer 2018-06-30 2018-07-01
# 7     107        Naveen        IT           Testing 2015-08-23 2015-11-24
# 8     108         Prema        IT           Testing 2023-12-17        NaT
# 9     109       Charles     sales     Sales Manager 2024-07-16        NaT
# 10    110         Ashok        IT         Developer 2024-03-13        NaT
#
#      salary  bonus  bonusamt   location        mobile gender
# 0   25000.0   0.10    2500.0    chennai  7.787543e+09      M
# ...

# %%
dfemp.mobile=dfemp['mobile'].astype("int64")

# %%
dfemp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 0 to 10
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   empid     10 non-null     int64
#  1   ename     10 non-null     object
#  2   dept      10 non-null     object
#  3   desig     10 non-null     object
#  4   doj       10 non-null     datetime64[ns]
#  5   doc       5 non-null      datetime64[ns]
#  6   salary    10 non-null     float64
#  7   bonus     10 non-null     float64
#  8   bonusamt  10 non-null     float64
#  9   location  10 non-null     object
#  10  mobile    10 non-null     int64
#  11  gender    10 non-null     object
# dtypes: datetime64[ns](2), float64(3), int64(2), object(5)
# memory usage: 1.0+ KB

# %%
dfemp
# Out:
#     empid         ename      dept             desig        doj        doc  \
# 0     101       Rajaram     sales   Sales Executive 2019-01-10 2019-07-11
# 1     102         Ramya     sales   Sales Executive 2021-02-15 2021-08-16
# 2     103      Gayathri  accounts           Manager 2023-01-19        NaT
# 3     104       Shabeer  accounts  Junior Executive 2023-02-26        NaT
# 4     105  Suresh Kumar     sales     Sales Manager 2016-04-29 2016-09-30
# 5     106       Kesavan        IT         Developer 2018-06-30 2018-07-01
# 7     107        Naveen        IT           Testing 2015-08-23 2015-11-24
# 8     108         Prema        IT           Testing 2023-12-17        NaT
# 9     109       Charles     sales     Sales Manager 2024-07-16        NaT
# 10    110         Ashok        IT         Developer 2024-03-13        NaT
#
#      salary  bonus  bonusamt   location      mobile gender
# 0   25000.0   0.10    2500.0    chennai  7787543211      M
# ...

# %%
dfemp.groupby(['dept']).salary.sum()
# Out:
# dept
# IT          143000.0
# accounts     25000.0
# sales       111000.0
# Name: salary, dtype: float64

# %%
dfemp.groupby(['dept','desig']).salary.sum()
# Out:
# dept      desig
# IT        Developer           105000.0
#           Testing              38000.0
# accounts  Junior Executive     10000.0
#           Manager              15000.0
# sales     Sales Executive      35000.0
#           Sales Manager        76000.0
# Name: salary, dtype: float64

# %%
dfempsummary=dfemp.groupby(['dept','desig']).salary.sum()

# %%
dfempsummary
# Out:
# dept      desig
# IT        Developer           105000.0
#           Testing              38000.0
# accounts  Junior Executive     10000.0
#           Manager              15000.0
# sales     Sales Executive      35000.0
#           Sales Manager        76000.0
# Name: salary, dtype: float64

# %%
dfemp.query('dept=="sales"')
# Out:
#    empid         ename   dept            desig        doj        doc   salary  \
# 0    101       Rajaram  sales  Sales Executive 2019-01-10 2019-07-11  25000.0
# 1    102         Ramya  sales  Sales Executive 2021-02-15 2021-08-16  10000.0
# 4    105  Suresh Kumar  sales    Sales Manager 2016-04-29 2016-09-30  38000.0
# 9    109       Charles  sales    Sales Manager 2024-07-16        NaT  38000.0
#
#    bonus  bonusamt location      mobile gender
# 0   0.10    2500.0  chennai  7787543211      M
# 1   0.15    1500.0  chennai  9986744321      F
# 4   0.05    1900.0  chennai  7965432122      M
# 9   0.05    1900.0    delhi  1234567890      M

# %%
dfemp.query('salary<20000')
# Out:
#    empid     ename      dept             desig        doj        doc   salary  \
# 1    102     Ramya     sales   Sales Executive 2021-02-15 2021-08-16  10000.0
# 2    103  Gayathri  accounts           Manager 2023-01-19        NaT  15000.0
# 3    104   Shabeer  accounts  Junior Executive 2023-02-26        NaT  10000.0
# 8    108     Prema        IT           Testing 2023-12-17        NaT  12000.0
#
#    bonus  bonusamt location      mobile gender
# 1   0.15    1500.0  chennai  9986744321      F
# 2   0.10    1500.0  chennai  4432567899      F
# 3   0.15    1500.0    delhi  9955443142      M
# 8   0.10    1200.0  chennai  8765487654      F

# %%
dfemp.query('dept=="sales" and location=="chennai"')
# Out:
#    empid         ename   dept            desig        doj        doc   salary  \
# 0    101       Rajaram  sales  Sales Executive 2019-01-10 2019-07-11  25000.0
# 1    102         Ramya  sales  Sales Executive 2021-02-15 2021-08-16  10000.0
# 4    105  Suresh Kumar  sales    Sales Manager 2016-04-29 2016-09-30  38000.0
#
#    bonus  bonusamt location      mobile gender
# 0   0.10    2500.0  chennai  7787543211      M
# 1   0.15    1500.0  chennai  9986744321      F
# 4   0.05    1900.0  chennai  7965432122      M

# %%
dfemp[(dfemp.salary>10000) & (dfemp.dept=='sales')]
# Out:
#    empid         ename   dept            desig        doj        doc   salary  \
# 0    101       Rajaram  sales  Sales Executive 2019-01-10 2019-07-11  25000.0
# 4    105  Suresh Kumar  sales    Sales Manager 2016-04-29 2016-09-30  38000.0
# 9    109       Charles  sales    Sales Manager 2024-07-16        NaT  38000.0
#
#    bonus  bonusamt location      mobile gender
# 0   0.10    2500.0  chennai  7787543211      M
# 4   0.05    1900.0  chennai  7965432122      M
# 9   0.05    1900.0    delhi  1234567890      M

# %%
dfemp.fillna('Not Applicable')
# Out:
#     empid         ename      dept             desig        doj  \
# 0     101       Rajaram     sales   Sales Executive 2019-01-10
# 1     102         Ramya     sales   Sales Executive 2021-02-15
# 2     103      Gayathri  accounts           Manager 2023-01-19
# 3     104       Shabeer  accounts  Junior Executive 2023-02-26
# 4     105  Suresh Kumar     sales     Sales Manager 2016-04-29
# 5     106       Kesavan        IT         Developer 2018-06-30
# 7     107        Naveen        IT           Testing 2015-08-23
# 8     108         Prema        IT           Testing 2023-12-17
# 9     109       Charles     sales     Sales Manager 2024-07-16
# 10    110         Ashok        IT         Developer 2024-03-13
#
#                     doc   salary  bonus  bonusamt   location      mobile  \
# 0   2019-07-11 00:00:00  25000.0   0.10    2500.0    chennai  7787543211
# 1   2021-08-16 00:00:00  10000.0   0.15    1500.0    chennai  9986744321
# ...

# %%
dfemp.dropna()
# Out:
#    empid         ename   dept            desig        doj        doc   salary  \
# 0    101       Rajaram  sales  Sales Executive 2019-01-10 2019-07-11  25000.0
# 1    102         Ramya  sales  Sales Executive 2021-02-15 2021-08-16  10000.0
# 4    105  Suresh Kumar  sales    Sales Manager 2016-04-29 2016-09-30  38000.0
# 5    106       Kesavan     IT        Developer 2018-06-30 2018-07-01  60000.0
# 7    107        Naveen     IT          Testing 2015-08-23 2015-11-24  26000.0
#
#    bonus  bonusamt   location      mobile gender
# 0   0.10    2500.0    chennai  7787543211      M
# 1   0.15    1500.0    chennai  9986744321      F
# 4   0.05    1900.0    chennai  7965432122      M
# 5   0.05    3000.0      delhi  8989787893      M
# 7   0.05    1300.0  bangalore  4432567899      M

# %%
dfemp.ename=dfemp.ename.str.upper()

# %%
dfemp
# Out:
#     empid         ename      dept             desig        doj        doc  \
# 0     101       RAJARAM     sales   Sales Executive 2019-01-10 2019-07-11
# 1     102         RAMYA     sales   Sales Executive 2021-02-15 2021-08-16
# 2     103      GAYATHRI  accounts           Manager 2023-01-19        NaT
# 3     104       SHABEER  accounts  Junior Executive 2023-02-26        NaT
# 4     105  SURESH KUMAR     sales     Sales Manager 2016-04-29 2016-09-30
# 5     106       KESAVAN        IT         Developer 2018-06-30 2018-07-01
# 7     107        NAVEEN        IT           Testing 2015-08-23 2015-11-24
# 8     108         PREMA        IT           Testing 2023-12-17        NaT
# 9     109       CHARLES     sales     Sales Manager 2024-07-16        NaT
# 10    110         ASHOK        IT         Developer 2024-03-13        NaT
#
#      salary  bonus  bonusamt   location      mobile gender
# 0   25000.0   0.10    2500.0    chennai  7787543211      M
# ...

# %%
dfemp.to_excel('newemp.xlsx')
